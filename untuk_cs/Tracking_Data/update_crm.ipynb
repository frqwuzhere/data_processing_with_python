# %%
import pandas as pd
from datetime import datetime
import numpy as np
import time

# %%
df_crm = pd.read_excel("checkpoint_files/data_each_crm_updated.xlsx")

# %%
df_crm['CRM'].value_counts()
# Out:
# CRM
# WA_2060             10673
# WA_7778              2962
# WA_0036              2504
# WA_0056              2003
# Refill_WA_7778_2     1894
#                     ...
# WA_baru_1              60
# WA_0053                11
# WA 0038                 4
# WA_0054                 3
# nothing                 1
# Name: count, Length: 65, dtype: int64

# %%
# First data
# data_8194 = pd.read_excel("../data_blast/data_each_crm/Olivia/data_WA_Oliv_8194.xlsx")
# data_8195 = pd.read_excel("../data_blast/data_each_crm/Olivia/data_WA_Oliv_8195.xlsx")
data_8204 = pd.read_excel("../data_blast/data_each_crm/Magang - Afiqa/data_WA_8204_Afiqa.xlsx")
data_8272 = pd.read_excel("../data_blast/data_each_crm/Magang - Afrida/data_WA_8272_Afrida.xlsx")
data_8203 = pd.read_excel("../data_blast/data_each_crm/Magang - Annisa/data_WA_8203_Annisa.xlsx")
data_8197 = pd.read_excel("../data_blast/data_each_crm/Magang - Ika/data_WA_8197_Ika.xlsx")
data_1092 = pd.read_excel("../data_blast/data_each_crm/Magang - Naufal/data_WA_1092_Naufal.xlsx")
data_8271 = pd.read_excel("../data_blast/data_each_crm/Magang - Zhiva/data_WA_8271_Zhiva.xlsx")
# data_baru_1 = pd.read_excel("../data_blast/data_each_crm/baru_1/data_WA_baru_1.xlsx")
# data_baru_1_1 = pd.read_excel("../data_blast/data_each_crm/baru_1/data_WA_baru_1_1.xlsx")
# data_baru_2 = pd.read_excel("../data_blast/data_each_crm/baru_2/data_WA_baru_2.xlsx")
# data_baru_2_2 = pd.read_excel("../data_blast/data_each_crm/baru_2/data_WA_baru_2_1.xlsx")
data_cs_baru_1 = pd.read_excel("../data_blast/data_each_crm/Ari/data_WA_Ari_1.xlsx")
data_cs_baru_1_1 = pd.read_excel("../data_blast/data_each_crm/Ari/data_WA_Ari_1_1.xlsx")


# Refill data

# refill_2056 = pd.read_excel("../data_blast/data_each_crm/Vicky/refill_data_WA_2056_Vicky.xlsx")
# refill_2057 = pd.read_excel("../data_blast/data_each_crm/Vicky/refill_data_WA_2057_Vicky.xlsx")
# refill_0046 = pd.read_excel("../data_blast/data_each_crm/Shania/Refill_data_WA_0046_Shania.xlsx")
# refill_0047 = pd.read_excel("../data_blast/data_each_crm/Shania/Refill_data_WA_0047_Shania.xlsx")
# refill_0041 = pd.read_excel("../data_blast/data_each_crm/Diah/Refill_data_WA_0041_Diah.xlsx")
# refill_0051 = pd.read_excel("../data_blast/data_each_crm/Diah/refill_data_WA_0051_Diah.xlsx")
# refill_2058 = pd.read_excel("../data_blast/data_each_crm/Endah/refill_data_WA_2058_Endah.xlsx")
# refill_2059 = pd.read_excel("../data_blast/data_each_crm/Endah/refill_data_WA_2059_Endah.xlsx")
# refill_1095 = pd.read_excel("../data_blast/data_each_crm/Firda/refill_data_WA_1095_Firda.xlsx")
# refill_1096 = pd.read_excel("../data_blast/data_each_crm/Firda/refill_data_WA_1096_Firda.xlsx")
# refill_0031 = pd.read_excel("../data_blast/data_each_crm/Erni/Refill_data_WA_0031_Erni.xlsx")
# refill_0032 = pd.read_excel("../data_blast/data_each_crm/Erni/Refill_data_WA_0032_Erni.xlsx")
# refill_0034 = pd.read_excel("../data_blast/data_each_crm/Agil/Refill_data_WA_0034_Agil.xlsx")
# refill_8196 = pd.read_excel("../data_blast/data_each_crm/Agil/Refill_data_WA_8196_Agil.xlsx")


# Refill data 2
# refill_0041_2nd = pd.read_excel("../data_blast/data_each_crm/Diah/Refill_data_2nd_WA_0041_Diah.xlsx")
# refill_1097_2nd = pd.read_excel("../data_blast/data_each_crm/Intan/Refill_data_2nd_WA_1097_Intan.xlsx")
# refill_0046_2nd = pd.read_excel("../data_blast/data_each_crm/Shania/Refill_data_2nd_WA_0046_Shania.xlsx")
# refill_0047_2nd = pd.read_excel("../data_blast/data_each_crm/Shania/Refill_data_2nd_WA_0047_Shania.xlsx")
# refill_0034_2nd = pd.read_excel("../data_blast/data_each_crm/Agil/Refill_data_2_WA_0034_Agil.xlsx")
# refill_2059_2nd = pd.read_excel("../data_blast/data_each_crm/Endah/Refill_data_2_WA_2059_Endah.xlsx")
# refill_0056_2nd = pd.read_excel("../data_blast/data_each_crm/Zein/Refill_data_2_WA_0056_Zein.xlsx")
# refill_1095_2nd = pd.read_excel("../data_blast/data_each_crm/Firda/Refill_data_2_WA_1095_Firda.xlsx")
# refill_2056_2nd = pd.read_excel("../data_blast/data_each_crm/Vicky/Refill_data_2_WA_2056_Vicky.xlsx")
# refill_2057_2nd = pd.read_excel("../data_blast/data_each_crm/Vicky/Refill_data_2_WA_2057_Vicky.xlsx")
# refill_0051_2nd = pd.read_excel("../data_blast/data_each_crm/Diah/Refill_data_2nd_WA_0051_Diah.xlsx")
# refill_1096_2nd = pd.read_excel("../data_blast/data_each_crm/Firda/Refill_data_2_WA_1096_Firda.xlsx")
# refill_7778_2nd = pd.read_excel("../data_blast/data_each_crm/Intan/Refill_data_2_WA_7778_Intan.xlsx")



# CTWA
# ctwa_0034 = pd.read_excel("../data_blast/data_each_crm/Agil/CTWA_data_WA_0034_Agil.xlsx")
# ctwa_8196 = pd.read_excel("../data_blast/data_each_crm/Agil/CTWA_data_WA_1094_Agil.xlsx")
# ctwa_0041 = pd.read_excel("../data_blast/data_each_crm/Diah/CTWA_data_WA_0041_Diah.xlsx")
# ctwa_0051 = pd.read_excel("../data_blast/data_each_crm/Diah/CTWA_data_WA_0051_Diah.xlsx")
# ctwa_2058 = pd.read_excel("../data_blast/data_each_crm/Endah/CTWA_data_WA_2058_Endah.xlsx")
# ctwa_2059 = pd.read_excel("../data_blast/data_each_crm/Endah/CTWA_data_WA_2059_Endah.xlsx")
# ctwa_0031 = pd.read_excel("../data_blast/data_each_crm/Erni/CTWA_data_WA_0031_Erni.xlsx")
# ctwa_0032 = pd.read_excel("../data_blast/data_each_crm/Erni/CTWA_data_WA_0032_Erni.xlsx")
# ctwa_1095 = pd.read_excel("../data_blast/data_each_crm/Firda/CTWA_data_WA_1095_Firda.xlsx")
# ctwa_1096 = pd.read_excel("../data_blast/data_each_crm/Firda/CTWA_data_WA_1096_Firda.xlsx")
# ctwa_7778 = pd.read_excel("../data_blast/data_each_crm/Intan/CTWA_data_WA_7778_Intan.xlsx")
# ctwa_1097 = pd.read_excel("../data_blast/data_each_crm/Intan/CTWA_data_WA_1097_Intan.xlsx")
# ctwa_0038 = pd.read_excel("../data_blast/data_each_crm/Intan/CTWA_data_WA_0038_Intan.xlsx")
# ctwa_8194 = pd.read_excel("../data_blast/data_each_crm/Olivia/CTWA_data_WA_8194_Oliv.xlsx")
# ctwa_8195 = pd.read_excel("../data_blast/data_each_crm/Olivia/CTWA_data_WA_8195_Oliv.xlsx")
# ctwa_0046 = pd.read_excel("../data_blast/data_each_crm/Shania/CTWA_data_WA_0046_Shania.xlsx")
# ctwa_0047 = pd.read_excel("../data_blast/data_each_crm/Shania/CTWA_data_WA_0047_Shania.xlsx")
# ctwa_0053 = pd.read_excel("../data_blast/data_each_crm/Shania/CTWA_data_WA_0053_Shania.xlsx")
# ctwa_0054 = pd.read_excel("../data_blast/data_each_crm/Shania/CTWA_data_WA_0054_Shania.xlsx")
# ctwa_2056 = pd.read_excel("../data_blast/data_each_crm/Vicky/CTWA_data_WA_2056_Vicky.xlsx")
# ctwa_2057 = pd.read_excel("../data_blast/data_each_crm/Vicky/CTWA_data_WA_2057_Vicky.xlsx")
# ctwa_0036 = pd.read_excel("../data_blast/data_each_crm/Zein/CTWA_data_WA_0036_Zein.xlsx")
# ctwa_0056 = pd.read_excel("../data_blast/data_each_crm/Zein/CTWA_data_WA_0056_Zein.xlsx")

# %% [markdown]
# # CTWA

# %%
ctwa = pd.concat([ctwa_0034,ctwa_8196,ctwa_0041,ctwa_0051,ctwa_2058,ctwa_2059,ctwa_0031,ctwa_0032,ctwa_1095,ctwa_1096,ctwa_7778,ctwa_1097,ctwa_0038,ctwa_8194,ctwa_8195,ctwa_0046,ctwa_0047,ctwa_0053,ctwa_0054,ctwa_2056,ctwa_2057,ctwa_0036,ctwa_0056])

ctwa['Donatur'] = ctwa['Donatur'].fillna(ctwa['Nama Donatur'])
ctwa['Whatsapp'] = ctwa['Whatsapp'].fillna(ctwa['Whatsapps'])
# ctwa['Donasi'] = ctwa['Donasi'].fillna(ctwa['Donasi '])

# drop na on donasi column and get only CRM, Donatur, Whatsapp, Donasi
# ctwa = ctwa[['CRM','Donatur','Whatsapp','Donasi','Donasi ']].dropna(subset=['Donasi','Donasi '])

ctwa_all = ctwa[['CRM','Donatur','Whatsapp']]
ctwa_all['Whatsapp'] = ctwa_all['Whatsapp'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ctwa = pd.concat([ctwa_0034,ctwa_8196,ctwa_0041,ctwa_0051,ctwa_2058,ctwa_2059,ctwa_0031,ctwa_0032,ctwa_1095,ctwa_1096,ctwa_7778,ctwa_1097,ctwa_0038,ctwa_8194,ctwa_8195,ctwa_0046,ctwa_0047,ctwa_0053,ctwa_0054,ctwa_2056,ctwa_2057,ctwa_0036,ctwa_0056])
#       3 ctwa['Donatur'] = ctwa['Donatur'].fillna(ctwa['Nama Donatur'])
#       4 ctwa['Whatsapp'] = ctwa['Whatsapp'].fillna(ctwa['Whatsapps'])
#
# NameError: name 'ctwa_0034' is not defined

# %% [markdown]
# # ALL

# %%
data_crm = pd.concat([df_crm])
 
data_crm['Whatsapp'] = data_crm['Whatsapp'].fillna(0).astype(int)

# %%
# change the data in here
refill_all = pd.concat([data_cs_baru_1, data_cs_baru_1_1, data_8204, data_8203, data_1092, data_8197, data_8272, data_8271])

df_crm_all = pd.concat([data_crm,refill_all])

# keep the last one only if duplicated
df_crm_updated = df_crm_all.drop_duplicates(subset=['Whatsapp'],keep='last')

# %%
df_crm_all['CRM'].value_counts()
# Out:
# CRM
# WA_2060             10673
# WA_7778              2962
# WA_0036              2504
# WA_0056              2003
# Refill_WA_7778_2     1894
#                     ...
# WA_baru_1              60
# WA_0053                11
# WA 0038                 4
# WA_0054                 3
# nothing                 1
# Name: count, Length: 67, dtype: int64

# %%
df_crm_updated.to_excel("checkpoint_files/data_each_crm_updated.xlsx")
